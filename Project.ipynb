# %% [markdown]
# # Project
#
# # Exploratory Data Analysis in Python for Retail

# %%
#Python version
from platform import python_version
print("Python version is: ", python_version())
# Out:
# Python version is:  3.9.13

# %%
#Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
#import dataset
dataset = pd.read_csv("dataset.csv")

# %%
#Checking the first 5 columns of the dataset
dataset.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# 4      22.3680

# %%
#Checking the last 5 columns of the dataset
dataset.tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 9695  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9696  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9697  CA-2018-154116  15/12/2018   KM-16660     Consumer  United States
# 9698  CA-2017-105291  30/10/2017   SP-20920     Consumer  United States
# 9699  CA-2018-147032  31/07/2018   LB-16795  Home Office  United States
#
#                Cidade      Estado       ID_Produto        Categoria  \
# 9695        Inglewood  California  OFF-PA-10004569  Office Supplies
# 9696        Inglewood  California  OFF-AP-10000027  Office Supplies
# 9697        Inglewood  California  TEC-PH-10000675       Technology
# 9698  San Luis Obispo  California  OFF-FA-10003059  Office Supplies
# 9699       Wilmington    Delaware  OFF-PA-10003256  Office Supplies
#
#      SubCategoria  Valor_Venda
# 9695        Paper       22.830
# 9696   Appliances       54.320
# 9697       Phones      196.776
# 9698    Fasteners        3.620
# 9699        Paper       11.540

# %%
#Cheacking shape of dataset
dataset.shape
# Out:
# (9700, 11)

# %% [markdown]
# ### Exploratory Analysis

# %%
#checking coloumns of dataset
dataset.columns
# Out:
# Index(['ID_Pedido', 'Data_Pedido', 'ID_Cliente', 'Segmento', 'Pais', 'Cidade',
#        'Estado', 'ID_Produto', 'Categoria', 'SubCategoria', 'Valor_Venda'],
#       dtype='object')

# %%
#Checking types of data
dataset.dtypes
# Out:
# ID_Pedido        object
# Data_Pedido      object
# ID_Cliente       object
# Segmento         object
# Pais             object
# Cidade           object
# Estado           object
# ID_Produto       object
# Categoria        object
# SubCategoria     object
# Valor_Venda     float64
# dtype: object

# %%
#Statistical summary of the valor venda column
dataset["Valor_Venda"].describe()
# Out:
# count     9700.000000
# mean       230.469892
# std        627.504252
# min          0.444000
# 25%         17.248000
# 50%         54.272000
# 75%        209.932500
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
#Checking duplicate data
dataset[dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID_Pedido, Data_Pedido, ID_Cliente, Segmento, Pais, Cidade, Estado, ID_Produto, Categoria, SubCategoria, Valor_Venda]
# Index: []

# %%
#Null value
dataset.isnull().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Cidade          0
# Estado          0
# ID_Produto      0
# Categoria       0
# SubCategoria    0
# Valor_Venda     0
# dtype: int64

# %%
dataset.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# 4      22.3680

# %% [markdown]
# ### 1- City with the highest sales volume in the "office supplies" category

# %%
#Filter the dataframe by categorizing "Office Supplies"
categorize = dataset[dataset["Categoria"] == "Office Supplies"]

# %%
categorize.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 6  CA-2015-115812  09/06/2015   BH-11710   Consumer  United States
# 8  CA-2015-115812  09/06/2015   BH-11710   Consumer  United States
# 9  CA-2015-115812  09/06/2015   BH-11710   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
# 6      Los Angeles  California  OFF-AR-10002833  Office Supplies          Art
# 8      Los Angeles  California  OFF-BI-10003910  Office Supplies      Binders
# 9      Los Angeles  California  OFF-AP-10002892  Office Supplies   Appliances
#
#    Valor_Venda
# 2       14.620
# 4       22.368
# 6        7.280
# 8       18.504
# 9      114.900

# %%
#Group by city and calculate total of Valor_venda
total_sales_volume = categorize.groupby("Cidade")["Valor_Venda"].sum()

# %%
#City with the highest sales volume
City_Highest_Sales_Volume = total_sales_volume.idxmax()
print("The city with the highest sales volume in the office supplies category: ", City_Highest_Sales_Volume)
# Out:
# The city with the highest sales volume in the office supplies category:  New York City

# %%
#Checking the result
checking_result = total_sales_volume.sort_values(ascending = False)
print(checking_result)
# Out:
# Cidade
# New York City    68362.814
# Los Angeles      47098.100
# San Francisco    41771.198
# Seattle          34856.878
# Philadelphia     29313.687
#                    ...
# Ormond Beach         2.808
# Pensacola            2.214
# Jupiter              2.064
# Elyria               1.824
# Abilene              1.392
# Name: Valor_Venda, Length: 480, dtype: float64

# %% [markdown]
# ### 2 Total sale by order date

# %%
#Group by Data_Pedido of Valor_venda
total_sale_by_Data_Pedido = dataset.groupby("Data_Pedido")["Valor_Venda"].sum()
print(total_sale_by_Data_Pedido)
# Out:
# Data_Pedido
# 01/01/2018    1481.8280
# 01/02/2015     468.9000
# 01/02/2017     161.9700
# 01/03/2015    2203.1510
# 01/03/2016    1642.1744
#                 ...
# 31/10/2017    2346.5790
# 31/10/2018     523.9280
# 31/12/2015    5253.2700
# 31/12/2016    1381.3440
# 31/12/2017     731.7680
# Name: Valor_Venda, Length: 1226, dtype: float64

# %%
#Data_Pedido with highest sale volume
Data_Pedido_highest_sale = total_sale_by_Data_Pedido.idxmax()
print(Data_Pedido_highest_sale)
# Out:
# 18/03/2015

# %%
#Checking the result
result = total_sale_by_Data_Pedido.sort_values(ascending = False)
print(result)
# Out:
# Data_Pedido
# 18/03/2015    28106.716
# 02/10/2017    18452.972
# 22/10/2018    15158.877
# 23/03/2018    14816.068
# 08/09/2015    14228.428
#                 ...
# 01/10/2015        4.710
# 24/06/2015        4.272
# 28/01/2015        3.928
# 12/07/2018        3.816
# 19/07/2016        2.025
# Name: Valor_Venda, Length: 1226, dtype: float64

# %%
#Plot
plt.figure(figsize = (20,6))
result.plot(x = "Data_Pedido", y = "Valor_Venda", color = "blue")
plt.title(" Total sale by order date")
plt.show()

# %% [markdown]
# ### 3 What is the total sales by state?

# %%
#Categorizing by state
Categorizing_by_state = dataset.groupby("Estado")["Valor_Venda"].sum().reset_index()
print(Categorizing_by_state)
# Out:
#                   Estado  Valor_Venda
# 0                Alabama   19510.6400
# 1                Arizona   35272.6570
# 2               Arkansas   11673.8300
# 3             California  442927.0975
# 4               Colorado   31841.5980
# 5            Connecticut   13366.7370
# 6               Delaware   26452.5890
# 7   District of Columbia    2865.0200
# 8                Florida   88043.7000
# 9                Georgia   48083.1600
# 10                 Idaho    4292.5160
# 11              Illinois   78109.9270
# 12               Indiana   48718.4000
# 13                  Iowa    4443.5600
# 14                Kansas    2914.3100
# 15              Kentucky   36409.5800
# 16             Louisiana    9131.0500
# 17                 Maine    1270.5300
# 18              Maryland   23705.5230
# 19         Massachusetts   27363.2640
# 20              Michigan   76081.1740
# 21             Minnesota   29863.1500
# 22           Mississippi   10771.3400
# 23              Missouri   22205.1500
# 24               Montana    5589.3520
# 25              Nebraska    7194.9500
# 26                Nevada   16729.1020
# 27         New Hampshire    7132.5440
# 28            New Jersey   34265.7120
# 29            New Mexico    4783.5220
# 30              New York  304536.4010
# 31        North Carolina   55165.9640
# 32          North Dakota     919.9100
# 33                  Ohio   74277.8020
# 34              Oklahoma   19683.3900
# 35                Oregon   17284.4620
# 36          Pennsylvania  114411.6800
# 37          Rhode Island   22525.0260
# 38        South Carolina    8481.7100
# 39          South Dakota    1315.5600
# 40             Tennessee   30661.8730
# 41                 Texas  163549.8602
# 42                  Utah   11220.0560
# 43               Vermont    4524.4700
# 44              Virginia   68194.6700
# 45            Washington  133826.0060
# 46         West Virginia    1209.8240
# 47             Wisconsin   31154.4700
# 48               Wyoming    1603.1360

# %%
#Plot
plt.figure(figsize = (16,6))
sns.barplot(data = Categorizing_by_state, x = "Estado", y = "Valor_Venda")
plt.title("Sale Total By State")
plt.xticks(rotation = 80)
plt.show()

# %% [markdown]
# ### 4 Which 10 cities have the highest total sales?

# %%
#Categorizing by cities
cities_with_highest_total_sales = dataset.groupby("Cidade")["Valor_Venda"].sum().reset_index()
result = cities_with_highest_total_sales.sort_values(by = 'Valor_Venda', ascending = False).head(10)

# %%
result.head(10)
# Out:
#             Cidade  Valor_Venda
# 327  New York City  251749.2190
# 265    Los Angeles  171654.6330
# 450        Seattle  114725.4780
# 436  San Francisco  107489.9520
# 372   Philadelphia  107197.8030
# 207        Houston   61590.1868
# 435      San Diego   47458.3790
# 80         Chicago   46974.3430
# 216   Jacksonville   44713.1830
# 123        Detroit   42446.9440

# %%
plt.figure(figsize = (16, 6))
sns.set_palette('coolwarm')
sns.barplot(data = result.head(10), x = 'Cidade', y = 'Valor_Venda')
plt.title("10 cities have the highest total sales")
plt.show()

# %% [markdown]
# ### 5 Which segment had the highest total sales

# %%
#Categorizing
categorizing_by_segment = dataset.groupby('Segmento')['Valor_Venda'].sum().reset_index()

# %%
result_categorizing_by_segment = categorizing_by_segment.sort_values(by = 'Valor_Venda', ascending = False)

# %%
result_categorizing_by_segment
# Out:
#       Segmento   Valor_Venda
# 0     Consumer  1.133834e+06
# 1    Corporate  6.792322e+05
# 2  Home Office  4.224914e+05

# %%
#Covert datas to absolute value
#Function to convert data to absolute value
def autopct_format(values):
    def my_format(pct):
        total = sum(values)
        val = int(round(pct*total/100.0))
        return '$ {v:d}'.format(v=val)
    return my_format

# %%
#Plot using Pizza Graphic

#Figure size
plt.figure(figsize = (16,6))

#Pie Chart
plt.pie(result_categorizing_by_segment["Valor_Venda"],
        labels = result_categorizing_by_segment["Segmento"],
        autopct = autopct_format(result_categorizing_by_segment["Valor_Venda"])
       ,startangle = 90)

#Clean inside of the circle
centre_circle = plt.Circle((0,0), 0.80, fc = 'white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

#Labels and anotations
plt.annotate(text = 'Total de Vendas: ' + '$' + str(int(sum(result_categorizing_by_segment["Valor_Venda"]))), 
             xy =(-0.25, 0))
plt.title("Total de Vendas Por Segmento")
plt.show()

# %% [markdown]
# ### 6 Total sales by segment and by year

# %%
dataset.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 1  CA-2017-152156  08/11/2017   CG-12520   Consumer  United States
# 2  CA-2017-138688  12/06/2017   DV-13045  Corporate  United States
# 3  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
# 4  US-2016-108966  11/10/2016   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda
# 0     261.9600
# 1     731.9400
# 2      14.6200
# 3     957.5775
# 4      22.3680

# %%
#Total sales by segment
total_sales_by_segment = dataset.groupby("Segmento")["Valor_Venda"].sum()
total_sales_by_segment
# Out:
# Segmento
# Consumer       1.133834e+06
# Corporate      6.792322e+05
# Home Office    4.224914e+05
# Name: Valor_Venda, dtype: float64

# %%
#Convert date column to datetime
dataset['Data_Pedido'] = pd.to_datetime(dataset["Data_Pedido"], dayfirst = True)

# %%
dataset.dtypes
# Out:
# ID_Pedido               object
# Data_Pedido     datetime64[ns]
# ID_Cliente              object
# Segmento                object
# Pais                    object
# Cidade                  object
# Estado                  object
# ID_Produto              object
# Categoria               object
# SubCategoria            object
# Valor_Venda            float64
# dtype: object

# %%
#Extract the year by creating a new variable
dataset["Year"] = dataset["Data_Pedido"].dt.year

# %%
dataset.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda  Year
# 0     261.9600  2017
# 1     731.9400  2017
# 2      14.6200  2017
# 3     957.5775  2016
# 4      22.3680  2016

# %%
#Total sales by year
Total_sales_by_year = dataset.groupby("Year")["Valor_Venda"].sum()
Total_sales_by_year
# Out:
# Year
# 2015    470768.6001
# 2016    454072.5154
# 2017    595365.9240
# 2018    715350.9152
# Name: Valor_Venda, dtype: float64

# %%
#Total sales by segment and_year 
Total_sales_by_segment_and_year = dataset.groupby(["Segmento", "Year"])["Valor_Venda"].sum()
Total_sales_by_segment_and_year
# Out:
# Segmento     Year
# Consumer     2015    256719.9166
#              2016    265295.2593
#              2017    288459.5572
#              2018    323359.6019
# Corporate    2015    125819.5957
#              2016    114643.1229
#              2017    203266.7398
#              2018    235502.7284
# Home Office  2015     88229.0878
#              2016     74134.1332
#              2017    103639.6270
#              2018    156488.5849
# Name: Valor_Venda, dtype: float64

# %% [markdown]
# #### The company manager wishes to offer a discount following the rules below:
# #### 1) If Sales Value is over 1000, get a 15% discount
# #### 2) If Sales Value is under 1000, get a 10% discount
#
# ### 7 How many Sales will receive a 15% discount

# %%
dataset["Discount"] = np.where(dataset["Valor_Venda"] > 1000, 0.15, 0.10)

# %%
dataset.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda  Year  Discount
# 0     261.9600  2017       0.1
# 1     731.9400  2017       0.1
# 2      14.6200  2017       0.1
# 3     957.5775  2016       0.1
# 4      22.3680  2016       0.1

# %%
dataset["Discount"].value_counts()
# Out:
# 0.10    9243
# 0.15     457
# Name: Discount, dtype: int64

# %%
print("So 457 values will receive a 15% discount")
# Out:
# So 457 values will receive a 15% discount

# %% [markdown]
# #### Consider that the company decides to grant a 15% discount on the previous item.
# ### 8 What would be the average sales value before and after the discount?

# %%
#All values affected by 15%
before_discount15 = dataset[dataset['Discount'] == 0.15]
before_discount15.head()
# Out:
#          ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 10  CA-2015-115812  2015-06-09   BH-11710   Consumer  United States
# 24  CA-2016-106320  2016-09-25   EB-13870   Consumer  United States
# 27  US-2016-150630  2016-09-17   TB-21520   Consumer  United States
# 35  CA-2017-117590  2017-12-08   GH-14485  Corporate  United States
# 54  CA-2017-105816  2017-12-11   JM-15265  Corporate  United States
#
#            Cidade        Estado       ID_Produto   Categoria SubCategoria  \
# 10    Los Angeles    California  FUR-TA-10001539   Furniture       Tables
# 24           Orem          Utah  FUR-TA-10000577   Furniture       Tables
# 27   Philadelphia  Pennsylvania  FUR-BO-10004834   Furniture    Bookcases
# 35     Richardson         Texas  TEC-PH-10004977  Technology       Phones
# 54  New York City      New York  TEC-PH-10002447  Technology       Phones
#
#     Valor_Venda  Year  Discount
# 10     1706.184  2015      0.15
# 24     1044.630  2016      0.15
# 27     3083.430  2016      0.15
# 35     1097.544  2017      0.15
# 54     1029.950  2017      0.15

# %%
#Average of all values before the 15% discount
average_before_discount15 = before_discount15.groupby("Discount")['Valor_Venda'].mean()

# %%
print(average_before_discount15)
# Out:
# Discount
# 0.15    2116.807815
# Name: Valor_Venda, dtype: float64

# %%
#All value after 15% discount
dataset["Valor_Venda_With_Discount"] = dataset["Valor_Venda"] - (dataset["Valor_Venda"]*dataset["Discount"])
dataset.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda  Year  Discount  Valor_Venda_With_Discount
# 0     261.9600  2017       0.1                  235.76400
# 1     731.9400  2017       0.1                  658.74600
# 2      14.6200  2017       0.1                   13.15800
# 3     957.5775  2016       0.1                  861.81975
# 4      22.3680  2016       0.1                   20.13120

# %%
discount15 = dataset[dataset["Discount"] == 0.15]

# %%
groupby_discount15 = discount15.groupby("Discount")["Valor_Venda_With_Discount"]

# %%
#Average of all values affected by 15
average_after_discount15 = groupby_discount15.mean()

# %%
print(average_after_discount15)
# Out:
# Discount
# 0.15    1799.286643
# Name: Valor_Venda_With_Discount, dtype: float64

# %% [markdown]
# ### 9 What is the average sales per segment, per year and per month?

# %%
#Create the column of the month
dataset["Month"] = dataset["Data_Pedido"].dt.month

# %%
dataset.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda  Year  Discount  Valor_Venda_With_Discount  Month
# 0     261.9600  2017       0.1                  235.76400     11
# 1     731.9400  2017       0.1                  658.74600     11
# 2      14.6200  2017       0.1                   13.15800      6
# 3     957.5775  2016       0.1                  861.81975     10
# 4      22.3680  2016       0.1                   20.13120     10

# %%
#Group by year, by month and segment,and calculate aggregation statistics
dataset1 = dataset.groupby(['Year', "Month", 'Segmento'])["Valor_Venda"].agg([np.sum, np.mean, np.median])

# %%
dataset1
# Out:
#                                sum        mean  median
# Year Month Segmento
# 2015 1     Consumer      6896.6290  146.736787  36.440
#            Corporate     1701.5280  130.886769  51.940
#            Home Office   5607.5500  329.855882  62.820
#      2     Consumer      3167.8540  117.327926  22.776
#            Corporate      623.1180   69.235333  62.310
# ...                            ...         ...     ...
# 2018 11    Corporate    44357.9862  341.215278  79.530
#            Home Office  24009.3840  247.519423  56.560
#      12    Consumer     48107.4558  183.616244  52.533
#            Corporate    20524.4320  153.167403  46.460
#            Home Office  13022.3910  224.523983  49.260
#
# [144 rows x 3 columns]

# %%
#Extract the levels
year = dataset1.index.get_level_values(0)
month = dataset1.index.get_level_values(1)
segment = dataset1.index.get_level_values(2)

# %%
#Plot
plt.figure(figsize = (12,6))
sns.set()
fig1 = sns.relplot(kind = 'line',
                  data = dataset1,
                  y = 'mean',
                  x = month,
                  hue = segment,
                  col = year,
                  col_wrap =4)
plt.show()

# %%
#Plot
plt.figure(figsize = (12,6))
sns.set()
fig1 = sns.relplot(kind = 'line',
                  data = dataset1,
                  y = 'sum',
                  x = month,
                  hue = segment,
                  col = year,
                  col_wrap =4)
plt.show()

# %%
#Plot
plt.figure(figsize = (12,6))
sns.set()
fig1 = sns.relplot(kind = 'line',
                  data = dataset1,
                  y = 'median',
                  x = month,
                  hue = segment,
                  col = year,
                  col_wrap =4)
plt.show()

# %% [markdown]
# ### 10 What The Total Sales By Categories e Subcategories For only Top 12 Subcategories

# %%
dataset.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais  \
# 0  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 1  CA-2017-152156  2017-11-08   CG-12520   Consumer  United States
# 2  CA-2017-138688  2017-06-12   DV-13045  Corporate  United States
# 3  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
# 4  US-2016-108966  2016-10-11   SO-20335   Consumer  United States
#
#             Cidade      Estado       ID_Produto        Categoria SubCategoria  \
# 0        Henderson    Kentucky  FUR-BO-10001798        Furniture    Bookcases
# 1        Henderson    Kentucky  FUR-CH-10000454        Furniture       Chairs
# 2      Los Angeles  California  OFF-LA-10000240  Office Supplies       Labels
# 3  Fort Lauderdale     Florida  FUR-TA-10000577        Furniture       Tables
# 4  Fort Lauderdale     Florida  OFF-ST-10000760  Office Supplies      Storage
#
#    Valor_Venda  Year  Discount  Valor_Venda_With_Discount  Month
# 0     261.9600  2017       0.1                  235.76400     11
# 1     731.9400  2017       0.1                  658.74600     11
# 2      14.6200  2017       0.1                   13.15800      6
# 3     957.5775  2016       0.1                  861.81975     10
# 4      22.3680  2016       0.1                   20.13120     10

# %%
#Group by Categorie and SubCategorie, and calculate only numeric sum
dataset2 = dataset.groupby(["Categoria", "SubCategoria"]).sum(numeric_only = True).sort_values("Valor_Venda", 
                                                                                               ascending = False).head(12)

# %%
# Convert the Sales Value column to an integer and sort by category
dataset3 =  dataset2[['Valor_Venda']].astype(int).sort_values(by = 'Categoria').reset_index()

# %%
# Dataframe with categories and subcategories
dataset3
# Out:
#           Categoria SubCategoria  Valor_Venda
# 0         Furniture       Chairs       317919
# 1         Furniture       Tables       202083
# 2         Furniture    Bookcases       108045
# 3         Furniture  Furnishings        88862
# 4   Office Supplies      Storage       216188
# 5   Office Supplies      Binders       194723
# 6   Office Supplies   Appliances       104061
# 7   Office Supplies        Paper        76312
# 8        Technology       Phones       325271
# 9        Technology     Machines       189238
# 10       Technology  Accessories       162791
# 11       Technology      Copiers       146248

# %%
#Create another dataframe with only the totals by category
dataset3_cat = dataset3.groupby('Categoria').sum(numeric_only = True).reset_index()

# %%
# Dataframe with categories
dataset3_cat
# Out:
#          Categoria  Valor_Venda
# 0        Furniture       716909
# 1  Office Supplies       591284
# 2       Technology       823548

# %%
# Color lists for categories
colors_categories = ['#5d00de',
                    '#0ee84f',
                    '#e80e27']

# %%
# Color lists for subcategories
colors_subcategories = ['#aa8cd4',
                       '#aa8cd5',
                       '#aa8cd6',
                       '#aa8cd7',
                       '#26c957',
                       '#26c958',
                       '#26c959',
                       '#26c960',
                       '#e65e65',
                       '#e65e66',
                       '#e65e67',
                       '#e65e68']

# %%
# Plot

# Size of the figure
fig, ax = plt.subplots(figsize = (18,12))

# Graphics of the categories
p1 = ax.pie(dataset3_cat['Valor_Venda'], 
            radius = 1,
            labels = dataset3_cat['Categoria'],
            wedgeprops = dict(edgecolor = 'white'),
            colors = colors_categories)

# Graphics of the subcategories
p2 = ax.pie(dataset3['Valor_Venda'],
            radius = 0.9,
            labels = dataset3['SubCategoria'],
            autopct = autopct_format(dataset3['Valor_Venda']),
            colors = colors_subcategories, 
            labeldistance = 0.7,
            wedgeprops = dict(edgecolor = 'white'), 
            pctdistance = 0.53,
            rotatelabels = True)

# Clean the center of the circle
centre_circle = plt.Circle((0, 0), 0.6, fc = 'white')

# Labels and notes
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.annotate(text = 'Total de Vendas: ' + '$ ' + str(int(sum(dataset3['Valor_Venda']))), xy = (-0.2, 0))
plt.title('Total de Vendas Por Categoria e Top 12 SubCategorias')
plt.show()
